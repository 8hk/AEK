# %%
#############################################################################################################
#   Retrieves Pudmed Articles                                                                               #
#                                                                                                           #
#   Entrez REST API:                                                                                        #
#   https://eutils.ncbi.nlm.nih.gov/entrez/eutils/                                                          #
#                                                                                                           #
#   Example:                                                                                                #
#   https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term=science[journal]              #
#   +AND+breast+cancer+AND+2008[pdat]                                                                       #
#                                                                                                           #
#############################################################################################################

# %%
import ontology_retriever as onRe

print("Retrieving all concepts in the following list of ontologies: ", onRe.list_of_bioportal_ontologies)
concepts = onRe.retrieve_annotations("dde26f65-ec2b-49b4-b3e7-090e5da33350", max_page_limit=10)
# Out:
# Retrieving all concepts in the following list of ontologies:  ['MFOMD', 'EDAM-BIOIMAGING', 'ICF', 'SYMP', 'GSSO', 'ENVO', 'MONDO', 'SNOMEDCT', 'DOID', 'MESH', 'RCD', 'NDDF']
# Ontology: MFOMD
# 	Page:  1 / 18
# 		Number of classes in this page:  50
# 	Page:  2 / 18
# 		Number of classes in this page:  50
# 	Page:  3 / 18
# 		Number of classes in this page:  50
# 	Page:  4 / 18
# 		Number of classes in this page:  50
# 	Page:  5 / 18
# 		Number of classes in this page:  50
# 	Page:  6 / 18
# 		Number of classes in this page:  50
# 	Page:  7 / 18
# 		Number of classes in this page:  50
# 	Page:  8 / 18
# 		Number of classes in this page:  50
# 	Page:  9 / 18
# 		Number of classes in this page:  50
# 	Page:  10 / 18
# 		Number of classes in this page:  50
# Ontology: EDAM-BIOIMAGING
# 	Page:  1 / 7
# 		Number of classes in this page:  50
# 	Page:  2 / 7
# 		Number of classes in this page:  50
# 	Page:  3 / 7
# 		Number of classes in this page:  50
# 	Page:  4 / 7
# 		Number of classes in this page:  50
# 	Page:  5 / 7
# 		Number of classes in this page:  50
# 	Page:  6 / 7
# 		Number of classes in this page:  50
# 	Page:  7 / 7
# 		Number of classes in this page:  41
# Ontology: ICF
# 	Page:  1 / 32
# 		Number of classes in this page:  50
# 	Page:  2 / 32
# 		Number of classes in this page:  50
# 	Page:  3 / 32
# 		Number of classes in this page:  50
# 	Page:  4 / 32
# 		Number of classes in this page:  50
# 	Page:  5 / 32
# 		Number of classes in this page:  50
# 	Page:  6 / 32
# 		Number of classes in this page:  50
# 	Page:  7 / 32
# 		Number of classes in this page:  50
# 	Page:  8 / 32
# 		Number of classes in this page:  50
# 	Page:  9 / 32
# 		Number of classes in this page:  50
# 	Page:  10 / 32
# 		Number of classes in this page:  50
# Ontology: SYMP
# 	Page:  1 / 19
# 		Number of classes in this page:  50
# 	Page:  2 / 19
# 		Number of classes in this page:  50
# 	Page:  3 / 19
# 		Number of classes in this page:  50
# 	Page:  4 / 19
# 		Number of classes in this page:  50
# 	Page:  5 / 19
# 		Number of classes in this page:  50
# 	Page:  6 / 19
# 		Number of classes in this page:  50
# 	Page:  7 / 19
# 		Number of classes in this page:  50
# 	Page:  8 / 19
# 		Number of classes in this page:  50
# 	Page:  9 / 19
# 		Number of classes in this page:  50
# 	Page:  10 / 19
# 		Number of classes in this page:  50
# Ontology: GSSO
# 	Page:  1 / 206
# 		Number of classes in this page:  50
# 	Page:  2 / 206
# 		Number of classes in this page:  50
# 	Page:  3 / 206
# 		Number of classes in this page:  50
# 	Page:  4 / 206
# 		Number of classes in this page:  50
# 	Page:  5 / 206
# 		Number of classes in this page:  50
# 	Page:  6 / 206
# 		Number of classes in this page:  50
# 	Page:  7 / 206
# 		Number of classes in this page:  50
# 	Page:  8 / 206
# 		Number of classes in this page:  50
# 	Page:  9 / 206
# 		Number of classes in this page:  50
# 	Page:  10 / 206
# 		Number of classes in this page:  50
# Ontology: ENVO
# 	Page:  1 / 124
# 		Number of classes in this page:  50
# 	Page:  2 / 124
# 		Number of classes in this page:  50
# 	Page:  3 / 124
# 		Number of classes in this page:  50
# 	Page:  4 / 124
# 		Number of classes in this page:  50
# 	Page:  5 / 124
# 		Number of classes in this page:  50
# 	Page:  6 / 124
# 		Number of classes in this page:  50
# 	Page:  7 / 124
# 		Number of classes in this page:  50
# 	Page:  8 / 124
# 		Number of classes in this page:  50
# 	Page:  9 / 124
# 		Number of classes in this page:  50
# 	Page:  10 / 124
# 		Number of classes in this page:  50
# Ontology: MONDO
# 	Page:  1 / 472
# 		Number of classes in this page:  50
# 	Page:  2 / 472
# 		Number of classes in this page:  50
# 	Page:  3 / 472
# 		Number of classes in this page:  50
# 	Page:  4 / 472
# 		Number of classes in this page:  50
# 	Page:  5 / 472
# 		Number of classes in this page:  50
# 	Page:  6 / 472
# 		Number of classes in this page:  50
# 	Page:  7 / 472
# 		Number of classes in this page:  50
# 	Page:  8 / 472
# 		Number of classes in this page:  50
# 	Page:  9 / 472
# 		Number of classes in this page:  50
# 	Page:  10 / 472
# 		Number of classes in this page:  50
# Ontology: SNOMEDCT
# 	Page:  1 / 7186
# 		Number of classes in this page:  50
# 	Page:  2 / 7186
# 		Number of classes in this page:  50
# 	Page:  3 / 7186
# 		Number of classes in this page:  50
# 	Page:  4 / 7186
# 		Number of classes in this page:  50
# 	Page:  5 / 7186
# 		Number of classes in this page:  50
# 	Page:  6 / 7186
# 		Number of classes in this page:  50
# 	Page:  7 / 7186
# 		Number of classes in this page:  50
# 	Page:  8 / 7186
# 		Number of classes in this page:  50
# 	Page:  9 / 7186
# 		Number of classes in this page:  50
# 	Page:  10 / 7186
# 		Number of classes in this page:  50
# Ontology: DOID
# 	Page:  1 / 379
# 		Number of classes in this page:  50
# 	Page:  2 / 379
# 		Number of classes in this page:  50
# 	Page:  3 / 379
# 		Number of classes in this page:  50
# 	Page:  4 / 379
# 		Number of classes in this page:  50
# 	Page:  5 / 379
# 		Number of classes in this page:  50
# 	Page:  6 / 379
# 		Number of classes in this page:  50
# 	Page:  7 / 379
# 		Number of classes in this page:  50
# 	Page:  8 / 379
# 		Number of classes in this page:  50
# 	Page:  9 / 379
# 		Number of classes in this page:  50
# 	Page:  10 / 379
# 		Number of classes in this page:  50
# Ontology: MESH
# 	Page:  1 / 5972
# 		Number of classes in this page:  50
# 	Page:  2 / 5972
# 		Number of classes in this page:  50
# 	Page:  3 / 5972
# 		Number of classes in this page:  50
# 	Page:  4 / 5972
# 		Number of classes in this page:  50
# 	Page:  5 / 5972
# 		Number of classes in this page:  50
# 	Page:  6 / 5972
# 		Number of classes in this page:  50
# 	Page:  7 / 5972
# 		Number of classes in this page:  50
# 	Page:  8 / 5972
# 		Number of classes in this page:  50
# 	Page:  9 / 5972
# 		Number of classes in this page:  50
# 	Page:  10 / 5972
# 		Number of classes in this page:  50
# Ontology: RCD
# 	Page:  1 / 2802
# 		Number of classes in this page:  50
# 	Page:  2 / 2802
# 		Number of classes in this page:  50
# 	Page:  3 / 2802
# 		Number of classes in this page:  50
# 	Page:  4 / 2802
# 		Number of classes in this page:  50
# 	Page:  5 / 2802
# 		Number of classes in this page:  50
# 	Page:  6 / 2802
# 		Number of classes in this page:  50
# 	Page:  7 / 2802
# 		Number of classes in this page:  50
# 	Page:  8 / 2802
# 		Number of classes in this page:  50
# 	Page:  9 / 2802
# 		Number of classes in this page:  50
# 	Page:  10 / 2802
# 		Number of classes in this page:  50
# Ontology: NDDF
# 	Page:  1 / 603
# 		Number of classes in this page:  50
# 	Page:  2 / 603
# 		Number of classes in this page:  50
# 	Page:  3 / 603
# 		Number of classes in this page:  50
# 	Page:  4 / 603
# 		Number of classes in this page:  50
# 	Page:  5 / 603
# 		Number of classes in this page:  50
# 	Page:  6 / 603
# 		Number of classes in this page:  50
# 	Page:  7 / 603
# 		Number of classes in this page:  50
# 	Page:  8 / 603
# 		Number of classes in this page:  50
# 	Page:  9 / 603
# 		Number of classes in this page:  50
# 	Page:  10 / 603
# 		Number of classes in this page:  50

# %%
import requests
import xmltodict

search_keyword="bipolar"
number_of_article=3

class Article:
    pmid = ""
    title = ""
    abstract = ""
    journal_issn = ""
    journal_name = ""

    def __init__(self, pmid, title,journal_issn, journal_name):
        self.pmid = pmid
        self.title = title
        self.journal_issn = journal_issn
        self.journal_name = journal_name


class EntrezSearchRequest:
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
    searchTerm = ""
    max_article_limit = 20

    def __init__(self, searchTerm, max_article_limit):
        self.searchTerm = searchTerm
        self.max_article_limit = max_article_limit

    def __str__(self):
        return self.base_url + "esearch.fcgi?db=pubmed&term=" + self.searchTerm + "&retmax=" + str(
            self.max_article_limit)


class EntrezGetAbstractRequest:
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
    id = 0

    def __init__(self, id):
        self.id = id

    def __str__(self):
        return self.base_url + "efetch.fcgi?db=pubmed&id=" + self.id + "&retmode=text&rettype=abstract"


class EntrezGetArticleRequest:
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
    id = 0

    def __init__(self, id):
        self.id = id

    def __str__(self):
        return self.base_url + "efetch.fcgi?db=pubmed&id=" + self.id + "&retmode=xml"


def retrieve_article_ids(search_term, max_article_limit):
    response = requests.get(EntrezSearchRequest(search_term, max_article_limit))

    if response.ok:
        xpars = xmltodict.parse(response.text)
        article_count = xpars['eSearchResult']['Count']
        returned_article_id_count = int(xpars['eSearchResult']['RetMax'])
        print("From " + article_count + " articles " + str(returned_article_id_count) + " article ids are retrieved")
        article_id_list = xpars['eSearchResult']['IdList']
        ''' 
        for id in range(0, int(returned_article_id_count)):
            print("\t"+xpars['eSearchResult']['IdList']['Id'][id])  
        '''
        return xpars['eSearchResult']['IdList']['Id']
    else:
        print("\tThis article id could not be retrieved.")


def get_abstract_of_given_article_id(id):
    response = requests.get(EntrezGetAbstractRequest(id))

    if response.ok:
        return response.text
    else:
        print("\tThis article abstract could not be retrieve for given id.")


def retrieve_articles(id):
    response = requests.get(EntrezGetArticleRequest(id))

    if response.ok:
        xpars = xmltodict.parse(response.text)
        article = xpars["PubmedArticleSet"]["PubmedArticle"]["MedlineCitation"]["Article"]
        article_title = article["ArticleTitle"]
        journal_issn = article["Journal"]["ISSN"]["#text"]
        journal_name = article["Journal"]["Title"]

        return Article(id, article_title, journal_issn, journal_name)
    else:
        print("\tArticle could not be retrieved.")

# %%
if __name__ == "__main__":

    print("Retrieving " + str(number_of_article) + " article pubmed ids from Pubmed related to: ", search_keyword)
    retrieved_article_ids = retrieve_article_ids(search_keyword, number_of_article)

    if len(retrieved_article_ids) > 0:
        for id in range(0, len(retrieved_article_ids)):
            print("Retrieving articles with pubmed id=" + str(retrieved_article_ids[id]))
            article = retrieve_articles(retrieved_article_ids[id])
            article.abstract=get_abstract_of_given_article_id(retrieved_article_ids[id])
            for c in concepts:
                if (c.pref_label in article.abstract):
                    print(
                        "Article with id: " + retrieved_article_ids[id] + " has ontolgy concept: " + c.id + " (synonyms=" + c.pref_label + ")")
# Out:
# Retrieving 3 article pubmed ids from Pubmed related to:  bipolar
# From 81435 articles 3 article ids are retrieved
# Retrieving articles with pubmed id=33307467
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/DOID_3312 (synonyms=bipolar disorder)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/OGMS_0000020 (synonyms=symptom)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/MFOMD_0000150 (synonyms=binge eating)
# Article with id: 33307467 has ontolgy concept: http://edamontology.org/format_ism (synonyms=ism)
# Article with id: 33307467 has ontolgy concept: http://edamontology.org/format_avi (synonyms=avi)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/SYMP_0000462 (synonyms=symptom)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/DOID_3312 (synonyms=bipolar disorder)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/CHEBI_23888 (synonyms=drug)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/PATO_0000367 (synonyms=right)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/MONDO_0005451 (synonyms=eating disorder)
# Article with id: 33307467 has ontolgy concept: http://purl.obolibrary.org/obo/DOID_3312 (synonyms=bipolar disorder)
# Article with id: 33307467 has ontolgy concept: http://purl.bioontology.org/ontology/NDDF/000859 (synonyms=tin)
# Retrieving articles with pubmed id=33307387
# Article with id: 33307387 has ontolgy concept: http://edamontology.org/operation_2990 (synonyms=Classification)
# Retrieving articles with pubmed id=33307307
# Article with id: 33307307 has ontolgy concept: http://purl.obolibrary.org/obo/BFO_0000034 (synonyms=function)
# Article with id: 33307307 has ontolgy concept: http://purl.obolibrary.org/obo/BFO_0000023 (synonyms=role)
# Article with id: 33307307 has ontolgy concept: http://edamontology.org/format_avi (synonyms=avi)
# Article with id: 33307307 has ontolgy concept: http://edamontology.org/format_tif (synonyms=tif)
# Article with id: 33307307 has ontolgy concept: http://purl.org/sig/ont/fma/fma59816 (synonyms=lip)
# Article with id: 33307307 has ontolgy concept: http://purl.obolibrary.org/obo/PATO_0000367 (synonyms=right)
# Article with id: 33307307 has ontolgy concept: http://purl.bioontology.org/ontology/NDDF/000859 (synonyms=tin)

# %%
response=requests.get("https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id="+str(33307467)+"&retmode=xml")
xpars = xmltodict.parse(response.text)
article = xpars["PubmedArticleSet"]["PubmedArticle"]["MedlineCitation"]["Article"]
article
# Out:
# OrderedDict([('@PubModel', 'Print-Electronic'),
#              ('Journal',
#               OrderedDict([('ISSN',
#                             OrderedDict([('@IssnType', 'Electronic'),
#                                          ('#text', '1873-7358')])),
#                            ('JournalIssue',
#                             OrderedDict([('@CitedMedium', 'Internet'),
#                                          ('Volume', '40'),
#                                          ('PubDate',
#                                           OrderedDict([('Year', '2020'),
#                                                        ('Month', 'Nov'),
#                                                        ('Day', '22')]))])),
#                            ('Title', 'Eating behaviors'),
#                            ('ISOAbbreviation', 'Eat Behav')])),
#              ('ArticleTitle',
#               'Symptoms of bipolar disorder are associated with lower bariatric surgery completion rates and higher food addiction.'),
#              ('Pagination', OrderedDict([('MedlinePgn', '101462')])),
#              ('ELocationID',
#               [OrderedDict([('@EIdType', 'pii'),
#                             ('@ValidYN', 'Y'),
#                             ('#text', 'S1471-0153(20)30381-0')]),
#                OrderedDict([('@EIdType', 'doi'),
#                             ('@ValidYN', 'Y'),
#                             ('#text', '10.1016/j.eatbeh.2020.101462')])]),
#              ('Abstract',
#               OrderedDict([('AbstractText',
#                             [OrderedDict([('@Label', 'BACKGROUND'),
#                                           ('@NlmCategory', 'BACKGROUND'),
#                                           ('#text',
#                                            'Bipolar disorder (BP) is highly comorbid with obesity, however, little is known about how BP might be associated with bariatric surgery outcomes.')]),
#                              OrderedDict([('@Label', 'METHODS'),
#                                           ('@NlmCategory', 'METHODS'),
#                                           ('#text',
#                                            'In this retrospective clinical cohort study, 1034 patients completed a psychological evaluation, and screening positive for possible BP was defined as a score\xa0≥7 and moderate disability on the Mood Disorders Questionnaire. Food addiction (FA), subthreshold binge eating disorder (BED), and illegal drug use were also assessed using standardized questionnaires.')]),
#                              OrderedDict([('@Label', 'RESULTS'),
#                                           ('@NlmCategory', 'RESULTS'),
#                                           ('#text',
#                                            'The 54 (5.2%) patients screening positive for BP were less likely to have bariatric surgery compared to 980 (94.8%) patients who screened negative for BP (5 patients or 9.3% vs 273 patients, or 27.9%). Patients with possible BP also had significantly higher prevalence of FA (37% vs 13.2%), subthreshold BED (29.6% vs 8.3%) and illegal drug use (7.4% vs 2.1%).')]),
#                              OrderedDict([('@Label', 'CONCLUSIONS'),
#                                           ('@NlmCategory', 'CONCLUSIONS'),
#                                           ('#text',
#                                            'In this retrospective clinical cohort study, patients who screened positive for BP had a higher prevalence of food addiction, subthreshold binge eating disorder and recent illegal drug use. They also demonstrated lower completion rates for having bariatric surgery. Clearly, more needs to be learned about how to help patients with symptoms of bipolar disorder manage their obesity and behavioral challenges.')])]),
#                            ('CopyrightInformation',
#                             'Copyright © 2020 Elsevier Ltd. All rights reserved.')])),
#              ('AuthorList',
#               OrderedDict([('@CompleteYN', 'Y'),
#                            ('Author',
#                             [OrderedDict([('@ValidYN', 'Y'),
#                                           ('LastName', 'Holgerson'),
#                                           ('ForeName', 'Allison A'),
#                                           ('Initials', 'AA'),
#                                           ('AffiliationInfo',
#                                            OrderedDict([('Affiliation',
#                                                          'Department of Psychiatry and Psychology, Mayo Clinic, Rochester, MN 55905, USA. Electronic address: aholgerson@phhp.ufl.edu.')]))]),
#                              OrderedDict([('@ValidYN', 'Y'),
#                                           ('LastName', 'Clark'),
#                                           ('ForeName', 'Matthew M'),
#                                           ('Initials', 'MM'),
#                                           ('AffiliationInfo',
#                                            OrderedDict([('Affiliation',
#                                                          'Department of Psychiatry and Psychology, Mayo Clinic, Rochester, MN 55905, USA. Electronic address: Clark.Matthew@mayo.edu.')]))]),
#                              OrderedDict([('@ValidYN', 'Y'),
#                                           ('LastName', 'Frye'),
#                                           ('ForeName', 'Mark A'),
#                                           ('Initials', 'MA'),
#                                           ('AffiliationInfo',
#                                            OrderedDict([('Affiliation',
#                                                          'Department of Psychiatry and Psychology, Mayo Clinic, Rochester, MN 55905, USA. Electronic address: MFrye@mayo.edu.')]))]),
#                              OrderedDict([('@ValidYN', 'Y'),
#                                           ('LastName', 'Kellogg'),
#                                           ('ForeName', 'Todd A'),
#                                           ('Initials', 'TA'),
#                                           ('AffiliationInfo',
#                                            OrderedDict([('Affiliation',
#                                                          'Department of Subspecialty General Surgery, Mayo Clinic, Rochester, MN 55905, USA. Electronic address: Kellogg.Todd@mayo.edu.')]))]),
#                              OrderedDict([('@ValidYN', 'Y'),
#                                           ('LastName', 'Mundi'),
#                                           ('ForeName', 'Manpreet S'),
#                                           ('Initials', 'MS'),
#                                           ('AffiliationInfo',
#                                            OrderedDict([('Affiliation',
#                                                          'Division of Endocrinology, Diabetes, Metabolism, & Nutrition, Department of Internal Medicine, Mayo Clinic, Rochester, MN 55905, USA. Electronic address: Mundi.Manpreet@mayo.edu.')]))]),
#                              OrderedDict([('@ValidYN', 'Y'),
#                                           ('LastName', 'Veldic'),
#                                           ('ForeName', 'Marin'),
#                                           ('Initials', 'M'),
#                                           ('AffiliationInfo',
#                                            OrderedDict([('Affiliation',
#                                                          'Department of Psychiatry and Psychology, Mayo Clinic, Rochester, MN 55905, USA. Electronic address: Veldic.Marin@mayo.edu.')]))]),
#                              OrderedDict([('@ValidYN', 'Y'),
#                                           ('LastName', 'Grothe'),
#                                           ('ForeName', 'Karen'),
#                                           ('Initials', 'K'),
#                                           ('AffiliationInfo',
#                                            OrderedDict([('Affiliation',
#                                                          'Department of Psychiatry and Psychology, Mayo Clinic, Rochester, MN 55905, USA. Electronic address: Grothe.Karen@mayo.edu.')]))])])])),
#              ('Language', 'eng'),
#              ('PublicationTypeList',
#               OrderedDict([('PublicationType',
#                             OrderedDict([('@UI', 'D016428'),
#                                          ('#text', 'Journal Article')]))])),
#              ('ArticleDate',
#               OrderedDict([('@DateType', 'Electronic'),
#                            ('Year', '2020'),
#                            ('Month', '11'),
#                            ('Day', '22')]))])

# %%
article["Abstract"]["AbstractText"]
# Out:
# [OrderedDict([('@Label', 'BACKGROUND'),
#               ('@NlmCategory', 'BACKGROUND'),
#               ('#text',
#                'Bipolar disorder (BP) is highly comorbid with obesity, however, little is known about how BP might be associated with bariatric surgery outcomes.')]),
#  OrderedDict([('@Label', 'METHODS'),
#               ('@NlmCategory', 'METHODS'),
#               ('#text',
#                'In this retrospective clinical cohort study, 1034 patients completed a psychological evaluation, and screening positive for possible BP was defined as a score\xa0≥7 and moderate disability on the Mood Disorders Questionnaire. Food addiction (FA), subthreshold binge eating disorder (BED), and illegal drug use were also assessed using standardized questionnaires.')]),
#  OrderedDict([('@Label', 'RESULTS'),
#               ('@NlmCategory', 'RESULTS'),
#               ('#text',
#                'The 54 (5.2%) patients screening positive for BP were less likely to have bariatric surgery compared to 980 (94.8%) patients who screened negative for BP (5 patients or 9.3% vs 273 patients, or 27.9%). Patients with possible BP also had significantly higher prevalence of FA (37% vs 13.2%), subthreshold BED (29.6% vs 8.3%) and illegal drug use (7.4% vs 2.1%).')]),
#  OrderedDict([('@Label', 'CONCLUSIONS'),
#               ('@NlmCategory', 'CONCLUSIONS'),
#               ('#text',
#                'In this retrospective clinical cohort study, patients who screened positive for BP had a higher prevalence of food addiction, subthreshold binge eating disorder and recent illegal drug use. They also demonstrated lower completion rates for having bariatric surgery. Clearly, more needs to be learned about how to help patients with symptoms of bipolar disorder manage their obesity and behavioral challenges.')])]
